# %% [markdown]
# # 3. 방정식과 도형

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 3.2 방정식을 그래프로 그리기
#
# (x, y) 좌표와 (x1,y1) 좌표 사이의 관계는 방정식으로 알 수 있다.
#
# ### 3.2.1 방정식
#
# 방정식은 문자를 포함하는 등식이다.
#
# 예를 들어 *사탕 30개를 세 개씩 아이들에게 나눠주고 여섯 개가 남았다. 아이들은 몇 명인가* 라는 문제를 풀 면
#  - 아이들은 x 로 두고  세 개씩 나눠주므로 3x
#  - 여섯개 남았으므로 6
#  - 모두 30개
#
#  이것을 등식으로 하면
#
#  $$
#  3x + 6 = 30
#  $$

# %% [markdown]
# 인원수 구하던 방정식에서 우변이 0이 되게 고치고 0을 y로 치환하면 아래 같은 식이 나온다.
#
#  $$
#  3x + 6 = 30\\
#  3x - 24 = 0 \\
#  y = 3x - 24
#  $$
#
# 이 y로 치환한 식이 함수이다. 함수는 **입력 하는 값이 정해지면 출력 값이 정해지는 식**이라고 한다. 즉 위 x라는 입력에 대해 y라는 출력을 정하는 것을 의미한다.
#
# 그래서 위 식도 x를 1...10까지 값을 순서데로 넣으면 아래 같이 만들 수 있다.

# %%
# 1.. 11 까지 3*x-24 식
y = []
for x in range(1, 15):
    y.append(3*x - 24)
print(y)
# Out:
# [-21, -18, -15, -12, -9, -6, -3, 0, 3, 6, 9, 12, 15, 18]

# %% [markdown]
# 위 방정식을 그래프로 그려보면 y = 0 일 때 x 좌표가 방정식 $ 3x + 6 = 30 $ 의 해이다.

# %%
# 위 방정식 x, y 값을 plot 으로 그려라
x = list(range(1, 15))

plt.plot(x, y)
plt.show()

# %% [markdown]
# 이렇게 방정식을 함수로 만들면 그래프도 그리고 그래프를 통해서 방정식의 해도 알 수 있다.

# %% [markdown]
# ### 3.2.3 함수와 그래프
#
# 함수는 x 값이 정해지면 Y 값이 정해지는 관계를 말하고 x의 차수(지수값)에 따라 일차함수, 이차함수, 삼차함수 같이 부른다.
#
# 이차함수
#
# $$
# y = x^2
# $$

# %%
# y = x^2 그래프를 그려라
x = np.arange(-1.0, 1.01, 0.01)
y = x**2

plt.plot(x, y)
plt.grid(color='0.8')
plt.show()

# %% [markdown]
# 삼차함수

# %%
x = np.arange(-1.0, 1.01, 0.01)
y = x**3 - x

plt.plot(x, y)
plt.grid(color='0.8')
plt.show()

# %% [markdown]
# ---
#
# ## 3.3 직선의 방정식
#
# 직선의 방정식은 좌표에서 한 점에서 다른 점 사이를 잇는 해를 찾는 방정식이다.
#
# ### 3.3.1 두 점을 잇는 직선
#
# 일차 함수가 두 점 사이를 이어주는 점의 해를 찾아 준다.
#
# $$
# y = ax + b
# $$
#
# 여기서 a는 **직선의 기울기**를 나타낸다. 이 기울기는 x가 변화함에 따라 y가 얼마나 변화하는 지를 나타내며 아래 같이 표현단다.
# $$
# \frac{y의 변화량}{x의 변화량}
# $$
#
# b는 y축과의 **절편**으로 y축과 직선이 교차하는 곳의 y좌표값이 된다.

# %% [markdown]
# 예를 들어서 좌표에 두 점 (1,1)과 (5,3) 이 있어서 두 점을 그려보면 x 좌표가 2 늘어나면 y가 1 늘어 나므로 기울기 $a = \frac{1}{2}$ 이고, 절편 $b = 0.5$ 가 된는 것을 알 수 있다. 이 직선의 일차함수 는
#
# $$
# y = \frac{1}{2} x + \frac{1}{2}
# $$
#
# 아래는 기울기를 1/2, 1/4로 했을 때의 그래프를 볼 수 있다.

# %%
# 기울기 1/2, 1/4 방정식을 계산해 그래프로 그려라.
x = np.arange(-5, 10, 0.5)
y = 1/2 * x + 1/2
y2 = 1/4 * x + 1/2

plt.plot(x, y, 'r')
plt.plot(x, y2, 'b')
plt.grid(color='0.8')
plt.show()

# %% [markdown]
# ---
#
#
# ### SymPy 이용 풀기
#
# 위 방정식을 sympy 를 사용해서 풀 수 있습니다.
#
# anaconda 에는 설치되어 있으므로 다음 같이 최신버전으로 업데이트해서 사용한다.
#
# ```
# conda update sympy
# ```
#
# pip 로 설치는
#
# ```
# pip install sympy
# ```

# %%
# sympy에서 Symbol, solve 클래스 임포트


a = # 심볼 a
b = # 심볼 b

ex1 = a + b - 1
ex2 = 5 * a + b - 3

# %%
# 풀기
print(solve((ex1, ex2)))
# Out:
# {a: 1/2, b: 1/2}

# %% [markdown]
# ### 3.3.2 직교하는 두 직선
#
# $y = a_1x + b_1$ 과 $y = a_2x + b_2$ 에서 두 직선의 **평행 조건**과 **직교 조건**은 아래 같다.
#
#  - **평행조건**: 두 직선의 식에서 $a_1 = a_2$ 면 두 직선은 평행이 된다.
#  - **직교조건**: $a_1 \times a_2 = -1 $ 일 때 두 직선은 서로 수직으로 교차한다.

# %% [markdown]
# 그러면 좌표 (1,5)를 지나며 앞의 $y = \frac{1}{2} x + \frac{1}{2}$ 와 직교하는 직선의 식은?
#
# 직선의 기울기 a는 직교 조건에 따라
#
# $$
# \frac{1}{2} \times a = -1 \\
# a = -2
# $$

# %% [markdown]
# 이 기울기 -2와 좌표 (1,5)를 $y = ax + b$ 에 대입하면
#
# $$
# 5 = -2\times 1 + b \\
# b = 7
# $$
#
# 그러므로 (1,5)와 식 $y = \frac{1}{2} x + \frac{1}{2}$ 의 직교하는 식은
#
# $$
# y = -2x + 7
# $$
#
# 이다.
#
# 위 $y = \frac{1}{2} x + \frac{1}{2}$ 와 직교하는 직선을 그려라.

# %%
# 직선1과 직선2 방정식을 폴어 그려라.
x = np.arange(-1, 6)
y = 1/2 * x + 1/2
y2 = -2*x + 7

plt.plot(x, y)
plt.plot(x, y2)

plt.axis('equal') # x,y axis 한계를 동일하게
plt.grid(color='0.8')
plt.show()

# %% [markdown]
# ### 3.3.3 두 직선의 교점
#
# 평면 좌표에 두 직선을 그릴 때 두 직선이 평행하지 않다면 어느 한 점에서 교차하게 되는데, 이때 이 교점이 두 직선의 식을 만족하는 점이며 이것이 연립방정식의 해입니다.

# %%
x = np.arange(-1, 6)
y = -3/2*x + 6            #식1
y2 = 1/2*x + 2             #식2

plt.plot(x, y)
plt.plot(x, y2)

plt.axis('equal')
plt.grid(color='0.8')
plt.show()

# %% [markdown]
# 연립방정식의 해를 SymPy 로 풀어보면

# %%
# 위 방정식의 해를 구하라.

x =    # 심볼 'x'
y =    # 'y'
ex1 =  #식1
ex2 =  #식2

#솔버
# Out:
# {x: 2.00000000000000, y: 3.00000000000000}

# %% [markdown]
# ---
#
# ## 3.4 비례식과 삼각비
#
# 1홉의 쌀로 밥을 지을 때 200ml 물을 넣는다. 다음에 2.5홉으로 밥을 지으려면 물을 얼마나 넣어야 하나요?
#
# 이런 문제는 비례식을 만들어서 해결이 가능합니다.
#
# ### 3.4.1 비례식의 성질
#
# 위 문제의 비례식은 아래 같습ㄴ디ㅏ.
#
#
# $$
# 1:200 = 2.5:x \\
# x = 200\times 2.5 \\
# x = 500
# $$
#
# 비례식은 내항과 외합의 곱한 값이 같다라는 성질이 있어어 이를 이용해 푼다.
#
# 또한 비례식은 비율을 분수식으로 처럼 나타낼 수 있다.
#
#
# $$
# a:b \rightarrow \frac{a}{b}
# $$

# %% [markdown]
# ### 3.4.2 선분, 내분점
#
# 어떤 두 점을 잇는 직성을 **선분** 이라하고 두 점을 지나 영원히 뻗는 선을 직선이라한다. 이런 선분을 $m:n$ 으로 나누는 점을 **내분점**이라 한다.
#
# <img src='https://t1.daumcdn.net/cfile/tistory/2447A938575C39FB2E' width='500'>
#
# y 방향의 내분점은
#
# $$
# y = \frac{my_{2} + ny_{1}}{m + n}
# $$

# %% [markdown]
# #### 중점
#
# 중점은 선분을 1:1로 내분하는 점이다. x, y 방향 내분점을 구하는 식의 m, n에 1을 대입해 보면 아래 등식이 성립한다.
#
# $$
# x = \frac{x_{1} + x_{2}}{2} \\
# y = \frac{y_{1} + y_{2}}{2}
# $$
#
# 시작점과 끝점의 x 좌표와 y 좌표를 각각 평균한 값이 중점의 좌표가 된다는 의미이다.
#
# (1,1), (4,5)의 중점 좌표는 계산에 의해 (2.5, 3) 이 된다.
#
# $$
# x = \frac{1+4}{2}, y = \frac{1+5}{2}
# $$

# %% [markdown]
# #### 수직이등분선
#
# 선분의 중점을 지나 그 선분과 직교하는 직선을 **수직이등분선** 이라고 한다.
#
# 두 점 (0, 1)과 (6,5) 를 잇는 선분의 수직이등분선을 나태내는 식은?
#
# 수직이등분선을 나탸내는 식은 아래 같은 순서로 구할 수 있다.
#
# 1. 선분의 기울기를 구한다. <---- 3.3.1
# 2. 선분의 중점을 구한다.
# 3. 선분과 직교하는 직선의 기울기를 구한다. <--- 3.3.2
# 4. 위 2에서 구한 좌표와 3의 기울기를 직선의 식에 대입해 절편을 구한다.
#
#
# 두점 (0,1)과 (6,5) 의 수직이등분선을 구해보면,

# %%
# 1.두 점 (0,1), (6,5)을 잇는 선분의 기울기
a1 = (5-1)/(6-0)

# 2.선분의 중점
cx = (0+6)/2
cy = (1+5)/2

# 3.선분의 직교 직선의 기울기
a2 = -1 /a1

# 4. b2 = y - a2 * x
b2 = cy - a2 * cx

# 두 직선의 함수
x = np.arange(0,7)
y1 = a1 * x + 1
y2 = a2 * x + b2

# 그래프 그리기
plt.plot(x, y1)
plt.plot(x, y2)
plt.axis('equal')
plt.grid(color='0.8')
plt.show()

# %% [markdown]
# ### 3.4.3 삼각비와 원
#
# 직각삼각형은 직각 이외의 각도가 한 개 정해지면 삼각형의 모양이 정해 진다. 이 각도룰 $\theta$ 라고 하고 $\theta$가 같은 직각삼각형은 변의 길이는 달라도 그 모양은 같다. 이런 도형을 닮은꼴이라고 한다.

# %% [markdown]
# 닮은꼴 대응하는 각 변의 비율은 같고 이것을 **닮은비**라고 한다.
#
# $$
# a1:a2 = b1:b2 = c1:c2
# $$
#
# a:b 같이 삼각형을 구성하는 변의 비율을 **형상비**라고 하고 이 비율은 가 $\theta$가 정해지면 자동으로 결정된다. 형상비 중에서 a:c, b:c, a:b 비율을 $\sin\theta$,$\cos\theta$,$\tan\theta$ 로 바꿔쓰고 이를 **삼각비**라고 한다.
#
# <img src='https://img1.daumcdn.net/thumb/R720x0.q80/?scode=mtistory2&fname=http%3A%2F%2Fcfile27.uf.tistory.com%2Fimage%2F2452084951DF77F9075AF7' width='400'>
#
# 그리고 각 $\theta$ 의 값이 한 가지로 정해지면 두 변의 비율도 한 가지로 정해지므로 이렇게 정해지는 것을 **삼각함수**라고 한다.

# %% [markdown]
# 삼각비를 이용해 원을 그릴 수 있다. 아래 그림은 반지름이 1인 원이다.
#
# <img src='https://lh3.googleusercontent.com/proxy/wuVVC6nbt0GRkQtxRwgut3BZmXGJCUtFMnbFo1GU_6v-jqEmYjSttaQuE1fw9orNr75bC34V24Ls3MuwLSTgsuPJeuwTyRMz7Q' width='250'>
#
# 이 원의 원주 위에 있는 점 P의 좌표(x,y) 와 중심을 잇는 직선이 x축과 만드는 각도를 $\theta$ 라고 하면 아래 식이 성립한다.
#
# $$
# \cos\theta = \frac{x}{1} \space \sin\theta = \frac{y}{1}
# $$

# %% [markdown]
# 위 식을 변형해 P 좌표는 $(\cos\theta, \sin\theta)$ 로 나타낼 수 있다. 반지름이 r이라면 위 식에 1을 r로 치환하면 원주 위 점 P의 좌표는 $(r\times \cos\theta, r\times \sin\theta)$ 가 된다.
#
# 각 $\theta$에 대응하는 sin, cos, tan 값은 삼각함수표에서 조사할 수 있다.
#
# <img src='https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&fname=https%3A%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F2157634352C79FF403' width='500'>

# %% [markdown]
# #### 삼각비를 이용해 원 그리기
#
#
# 여기서 NumPy의 sin(), cos() 이용해 원주의 P점을 얻을 수 있는데, 이때 **라디안** 이라 부르는 **호도법** 단위가 필요하다.
#
# 이제 중심이 0이고 반지름 1인 원을 그려보자,

# %%
#angle
th = np.arange(0, 360)

# 원주 위 P의 좌표
x =   # 라디안변환
y =   # 라디안변환



plt.plot(x, y)
plt.axis('equal')
plt.grid(color='0.8')
plt.show()
